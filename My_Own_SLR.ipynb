# %% [markdown]
# <a href="https://colab.research.google.com/github/1ashish1105/Machine_Learning/blob/main/My_Own_SLR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
class meraLR:
  def __init__(self):
    self.m=None
    self.b=None

  def fit(self,X_train,y_train):
    num=0;
    den=0;
    for i in range(X_train.shape[0]):
      num=num+((X_train.iloc[i]-X_train.mean())*(y_train.iloc[i]-y_train.mean()))
      den=den+((X_train.iloc[i]-X_train.mean())*(X_train.iloc[i]-X_train.mean()))
      self.m=num/den
      self.b=y_train.mean()-(self.m*X_train.mean())
      print(self.m)
      print(self.b)

  def predict(self,X_test):
    print(X_test)
    return ((self.m*X_test)+self.b)

# %%
df=pd.read_csv('placement.csv')

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
X=df.iloc[:,0:1]
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)

# %%
lr=meraLR()

# %%
lr.fit(X_train,y_train)
# Out:
# cgpa    0.840067
# dtype: float64
# cgpa   -2.868076
# dtype: float64
# cgpa    0.469246
# dtype: float64
# cgpa   -0.276063
# dtype: float64
# cgpa    0.473578
# dtype: float64
# cgpa   -0.306346
# dtype: float64
# cgpa    0.436811
# dtype: float64
# cgpa   -0.049347
# dtype: float64
# cgpa    0.490303
# dtype: float64
# cgpa   -0.423252
# dtype: float64
# cgpa    0.483969
# dtype: float64
# cgpa   -0.378978
# dtype: float64
# cgpa    0.486403
# dtype: float64
# cgpa   -0.395991
# dtype: float64
# cgpa    0.497032
# dtype: float64
# cgpa   -0.470286
# dtype: float64
# cgpa    0.471994
# dtype: float64
# cgpa   -0.295271
# dtype: float64
# cgpa    0.439748
# dtype: float64
# cgpa   -0.069875
# dtype: float64
# cgpa    0.475909
# dtype: float64
# cgpa   -0.322638
# dtype: float64
# cgpa    0.51634
# dtype: float64
# cgpa   -0.605245
# dtype: float64
# cgpa    0.521191
# dtype: float64
# cgpa   -0.639154
# dtype: float64
# cgpa    0.529162
# dtype: float64
# cgpa   -0.694869
# ...

# %%
print(lr.predict(X_test.iloc[0,0]))
# Out:
# 8.58
# cgpa    3.891116
# dtype: float64
